# %%
import matplotlib.pyplot as plt
import sys
import os
os.chdir('/home/jingyan/Documents/VAC_CSLR')
sys.path.append('.')
from utils.video_augmentation import *

# %%
import pickle

with open('.test/dataset.pt', 'rb') as f:
    dataset = pickle.load(f)

dev_set = dataset['train']
dataset
# Out:
# {'train': <dataset.dataloader_video.BaseFeeder at 0x7fc546ff5d60>,
#  'train_eval': <dataset.dataloader_video.BaseFeeder at 0x7fc539e43820>,
#  'dev': <dataset.dataloader_video.BaseFeeder at 0x7fc542d151c0>,
#  'test': <dataset.dataloader_video.BaseFeeder at 0x7fc539e4e700>}

# %%
transform = Compose(
    ToTensor()
)

dev_set.transforms = transform

# %%
from random import randint
data = dev_set[0][0][randint(0, 100)]
data = (data + 1) / 2.
plt.imshow(data.permute(1, 2, 0))
