# %%
import matplotlib.pyplot as plt
import sys
import os
os.chdir('/home/jingyan/Documents/VAC_CSLR')
sys.path.append('.')
from utils.video_augmentation import *

# %%
import pickle

with open('.test/dataset.pt', 'rb') as f:
    dataset = pickle.load(f)

dev_set = dataset['train_eval']
dataset
# Out:
# {'train': <dataset.dataloader_video.BaseFeeder at 0x7fddcc3f1940>,
#  'train_eval': <dataset.dataloader_video.BaseFeeder at 0x7fdceb0b64c0>,
#  'dev': <dataset.dataloader_video.BaseFeeder at 0x7fdceb0b60d0>,
#  'test': <dataset.dataloader_video.BaseFeeder at 0x7fdce48d4f40>}

# %%
transform = Compose(
    ToTensor()
)

dev_set.transforms = transform

# %%
from random import randint
data = dev_set[0][0][randint(0, 100)]
data = (data + 1) / 2.
plt.imshow(data.permute(1, 2, 0))
