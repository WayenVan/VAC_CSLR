# %%
import matplotlib.pyplot as plt
import sys
import os
os.chdir('/home/jingyan/Documents/VAC_CSLR')
sys.path.append('.')
from utils.video_augmentation import *

# %%
import pickle

with open('.test/dataset.pt', 'rb') as f:
    dataset = pickle.load(f)

dev_set = dataset['train_eval']
dataset
# Out:
# {'train': <dataset.dataloader_video.BaseFeeder at 0x7f31b8160f10>,
#  'train_eval': <dataset.dataloader_video.BaseFeeder at 0x7f30d6d616a0>,
#  'dev': <dataset.dataloader_video.BaseFeeder at 0x7f30d6d61550>,
#  'test': <dataset.dataloader_video.BaseFeeder at 0x7f30d06c9fd0>}

# %%
transform = Compose(
    ToTensor()
)

dev_set.transforms = transform

# %%
data = dev_set[0][0][100]
data = (data + 1) / 2.
data.shape
# Out:
# torch.Size([3, 224, 224])

# %%
plt.imshow(data.permute(1, 2, 0).numpy())
